# %%
import numpy as np
import itertools 
from ezc3d import c3d
import matplotlib.pyplot as plt
import pyomeca
#import dtw
from pathlib import Path
from math import sqrt
from pyomeca import Markers, Analogs
from tqdm import tqdm
import dataprocesing as dp
import warnings
warnings.filterwarnings("ignore")


data_path = r"C:\Users\Gmultimedia\Desktop\Praktyki_2020\2020-08-05-B0444-S01-E01-T01.c3d"
markers = Markers.from_c3d(data_path, prefix_delimiter=":")


ev = dp.read_labels(data_path,200)
print(ev)
s,k=dp.nowy_czas(36,ev,markers)
plt.show()

mm=[0,5,10,15,20,25]
for i in range(len(mm)):
    dp.przesuwanie_wykresow(ev,0,mm[i],s,k,markers)
# Out:
# [[664, 1320, 1960, 3480, 4269, 4975, 5964, 6462, 7077], [1320, 1960, 2508, 4269, 4975, 5490, 6462, 7077, 7609]]

# %%
import numpy as np
import itertools 
from ezc3d import c3d
import matplotlib.pyplot as plt
import pyomeca
#import dtw
from pathlib import Path
from math import sqrt
from pyomeca import Markers, Analogs
from tqdm import tqdm
import dataprocesing as dp
import warnings
warnings.filterwarnings("ignore")
data_path = r"C:\Users\Gmultimedia\Desktop\Praktyki_2020\2020-08-05-B0444-S01-E03-T03.c3d"
markers = Markers.from_c3d(data_path, prefix_delimiter=":")

ev = dp.read_labels(data_path,200)
s,k=dp.nowy_czas(36,ev,markers)
plt.show()

mm=[0,5,10,15,20,25]
for i in range(len(mm)):
    dp.przesuwanie_wykresow(ev,0,mm[i],s,k,markers)

# %%
import numpy as np
import itertools 
from ezc3d import c3d
import matplotlib.pyplot as plt
import pyomeca
#import dtw
from pathlib import Path
from math import sqrt
from pyomeca import Markers, Analogs
from tqdm import tqdm
import dataprocesing as dp
import warnings
warnings.filterwarnings("ignore")
data_path = r"C:\Users\Gmultimedia\Desktop\Praktyki_2020\2020-08-05-B0444-S01-E01-T02.c3d"
markers = Markers.from_c3d(data_path, prefix_delimiter=":")

ev = dp.read_labels(data_path,200)
s,k=dp.nowy_czas(36,ev,markers)
plt.show()

mm=[0,5,10,15,20,25]
for i in range(len(mm)):
    dp.przesuwanie_wykresow(ev,0,mm[i],s,k,markers)

# %%
markers = Markers.from_c3d(data_path, prefix_delimiter=":")

# %%
markers
