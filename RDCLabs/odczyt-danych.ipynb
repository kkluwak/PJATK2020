# %% [markdown]
# # Odczytywanie danych Motion Capture
# ---

# %% [markdown]
# ### Odczytywanie o pliku przy pomocy ezc3d

# %%
from ezc3d import c3d
data_path = "file.c3d"
file = c3d(data_path)
print("Ilość ramek to:", file['parameters']['POINT']['FRAMES']['value'][0])
# Out:
# Ilość ramek to: 2423

# %% [markdown]
# **Brakuje: informacji o:**
# - liczbie: ramek, markerów, danych analogowych, eventów
# - jednosktach dla: markerów, EMG, GRF, kątów, mocy, momentów, sił
# - nawach: markerów, danych analogowych, eventów
# - czym się rózni marker od markera wirtualnego?

# %% [markdown]
# ### Odczytywanie danych przy pomocy pyomeca
# - https://github.com/pyomeca/pyomeca
# - https://github.com/pyomeca/pyomeca/tree/master/notebooks

# %%
# conda install -c conda-forge pyomeca
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\konra\Anaconda3
#
#   added / updated specs:
#     - pyomeca
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.1.1             |     pyh9f0ad1d_0          25 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         184 KB  conda-forge
#     certifi-2020.6.20          |   py37hc8dfbb8_0         151 KB  conda-forge
#     conda-4.8.4                |   py37hc8dfbb8_1         3.1 MB  conda-forge
#     matplotlib-base-3.2.2      |   py37hab8957c_1         7.0 MB  conda-forge
#     openssl-1.1.1g             |       he774522_1         5.7 MB  conda-forge
#     pyomeca-2020.0.1           |     pyh9f0ad1d_0          35 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
# ...

# %%
from pyomeca import Analogs

data_path = "file.c3d"
muscles = ["Voltage.1"]
emg = Analogs.from_c3d(data_path, usecols=muscles)

# %%
import matplotlib as plt
emg.plot()
