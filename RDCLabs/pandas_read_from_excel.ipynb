# %%
import pandas as pd

# %%
x=pd.read_excel('adnotacja.xlsx', usecols='A:Y',skiprows=1, nrows=75 )
# print(x)
pd.read_excel('adnotacja.xlsx', usecols='A:Y',skiprows=1, nrows=75 )
# Out:
#     Osoba Ruch  wysokość jelca  pozycja sztychu  ustawienie stóp  \
# 0   B0444  E01               1                1                1
# 1   B0444  E02               1                1                1
# 2   B0444  E03               1                1                1
# 3   B0444  E04               1                1                1
# 4   B0444  E05               1                1                1
# ..    ...  ...             ...              ...              ...
# 70  B0458  E01               0                1                1
# 71  B0458  E02               0                1                1
# 72  B0458  E03               1                1                1
# 73  B0458  E04               0                1                1
# 74  B0458  E05               1                0                1
#
#     łokcie blisko siebie  ruch noga do poz. końcowej  \
# 0                      1                           1
# 1                      1                           1
# 2                      1                           1
# 3                      1                           1
# 4                      1                           1
# ..                   ...                         ...
# 70                     0                           1
# 71                     1                           1
# 72                     0                           1
# 73                     0                           0
# 74                     0                           1
#
#     wyprostoawnie w łokciach  wyrzut rąk do przodu  \
# 0                          1                     1
# 1                          1                     1
# 2                          1                     1
# 3                          1                     1
# 4                          1                     1
# ..                       ...                   ...
# 70                         1                     1
# 71                         1                     1
# 72                         1                     1
# 73                         1                     1
# 74                         1                     1
#
#     uderzenie odpowiednim ostrzem  ...  sztych ląduje po lewej  \
# 0                               1  ...                     NaN
# 1                               1  ...                     1.0
# 2                               1  ...                     NaN
# 3                               1  ...                     NaN
# 4                               1  ...                     NaN
# ..                            ...  ...                     ...
# 70                              1  ...                     NaN
# 71                              0  ...                     1.0
# 72                              0  ...                     NaN
# 73                              0  ...                     NaN
# 74                              1  ...                     NaN
#
#     poniesienie jelca nad głowę  poziomy ruch ostrza na wysokości głowy  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           1.0                                     1.0
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# ..                          ...                                     ...
# 70                          NaN                                     NaN
# 71                          NaN                                     NaN
# 72                          1.0                                     1.0
# 73                          NaN                                     NaN
# 74                          NaN                                     NaN
#
#     dokręcenie dłoni  skrzyżowanie rąk  odpowiednio mocne dokręcenie ostrza  \
# 0                NaN               NaN                                  NaN
# 1                NaN               NaN                                  NaN
# 2                1.0               NaN                                  NaN
# 3                NaN               1.0                                  1.0
# 4                NaN               NaN                                  NaN
# ..               ...               ...                                  ...
# 70               NaN               NaN                                  NaN
# 71               NaN               NaN                                  NaN
# 72               0.0               NaN                                  NaN
# 73               NaN               1.0                                  1.0
# 74               NaN               NaN                                  NaN
#
#     trzymanie rąk po prawej stronie  ruch wędkowy  \
# 0                               NaN           NaN
# 1                               NaN           NaN
# 2                               NaN           NaN
# 3                               1.0           NaN
# 4                               NaN           1.0
# ..                              ...           ...
# 70                              NaN           NaN
# 71                              NaN           NaN
# 72                              NaN           NaN
# 73                              1.0           NaN
# 74                              NaN           1.0
#
#     uderzenie po środku lini ciała  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              1.0
# ..                             ...
# 70                             NaN
# 71                             NaN
# 72                             NaN
# 73                             NaN
# 74                             0.0
#
#     po uderzeniu tylnia noga i plecy są w jednej linii
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 1.0
# ..                                                ...
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                1.0
#
# [75 rows x 25 columns]

# %%
x.values
# Out:
# array([['B0444', 'E01', 1, ..., nan, nan, nan],
#        ['B0444', 'E02', 1, ..., nan, nan, nan],
#        ['B0444', 'E03', 1, ..., nan, nan, nan],
#        ...,
#        ['B0458', 'E03', 1, ..., nan, nan, nan],
#        ['B0458', 'E04', 0, ..., nan, nan, nan],
#        ['B0458', 'E05', 1, ..., 1.0, 0.0, 1.0]], dtype=object)

# %%
print(x)
# Out:
#     Osoba Ruch  wysokość jelca  pozycja sztychu  ustawienie stóp  \
# 0   B0444  E01               1                1                1
# 1   B0444  E02               1                1                1
# 2   B0444  E03               1                1                1
# 3   B0444  E04               1                1                1
# 4   B0444  E05               1                1                1
# ..    ...  ...             ...              ...              ...
# 70  B0458  E01               0                1                1
# 71  B0458  E02               0                1                1
# 72  B0458  E03               1                1                1
# 73  B0458  E04               0                1                1
# 74  B0458  E05               1                0                1
#
#     łokcie blisko siebie  ruch noga do poz. końcowej  \
# 0                      1                           1
# 1                      1                           1
# 2                      1                           1
# 3                      1                           1
# 4                      1                           1
# ..                   ...                         ...
# 70                     0                           1
# 71                     1                           1
# 72                     0                           1
# 73                     0                           0
# 74                     0                           1
#
#     wyprostoawnie w łokciach  wyrzut rąk do przodu  \
# 0                          1                     1
# 1                          1                     1
# 2                          1                     1
# 3                          1                     1
# 4                          1                     1
# ..                       ...                   ...
# 70                         1                     1
# 71                         1                     1
# 72                         1                     1
# 73                         1                     1
# 74                         1                     1
#
#     uderzenie odpowiednim ostrzem  ...  sztych ląduje po lewej  \
# 0                               1  ...                     NaN
# 1                               1  ...                     1.0
# 2                               1  ...                     NaN
# 3                               1  ...                     NaN
# 4                               1  ...                     NaN
# ..                            ...  ...                     ...
# 70                              1  ...                     NaN
# 71                              0  ...                     1.0
# 72                              0  ...                     NaN
# 73                              0  ...                     NaN
# 74                              1  ...                     NaN
#
#     poniesienie jelca nad głowę  poziomy ruch ostrza na wysokości głowy  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           1.0                                     1.0
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# ..                          ...                                     ...
# 70                          NaN                                     NaN
# 71                          NaN                                     NaN
# 72                          1.0                                     1.0
# 73                          NaN                                     NaN
# 74                          NaN                                     NaN
#
#     dokręcenie dłoni  skrzyżowanie rąk  odpowiednio mocne dokręcenie ostrza  \
# 0                NaN               NaN                                  NaN
# 1                NaN               NaN                                  NaN
# 2                1.0               NaN                                  NaN
# 3                NaN               1.0                                  1.0
# 4                NaN               NaN                                  NaN
# ..               ...               ...                                  ...
# 70               NaN               NaN                                  NaN
# 71               NaN               NaN                                  NaN
# 72               0.0               NaN                                  NaN
# 73               NaN               1.0                                  1.0
# 74               NaN               NaN                                  NaN
#
#     trzymanie rąk po prawej stronie  ruch wędkowy  \
# 0                               NaN           NaN
# 1                               NaN           NaN
# 2                               NaN           NaN
# 3                               1.0           NaN
# 4                               NaN           1.0
# ..                              ...           ...
# 70                              NaN           NaN
# 71                              NaN           NaN
# 72                              NaN           NaN
# 73                              1.0           NaN
# 74                              NaN           1.0
#
#     uderzenie po środku lini ciała  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              1.0
# ..                             ...
# 70                             NaN
# 71                             NaN
# 72                             NaN
# 73                             NaN
# 74                             0.0
#
#     po uderzeniu tylnia noga i plecy są w jednej linii
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 1.0
# ..                                                ...
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                1.0
#
# [75 rows x 25 columns]
