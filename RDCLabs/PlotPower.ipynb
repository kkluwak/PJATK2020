# %%
import dataprocesing as dp
import numpy as np
import importlib
from ezc3d import c3d
import matplotlib.pyplot as plt

# %%
importlib.reload(dp)
data_path = "2020-08-05-B0444-S01-E01-T03.c3d"
data_path1 = "2020-08-06-B0445-S01-E01-T03.c3d"
data_path2 = "2020-08-06-B0446-S01-E01-T03.c3d"
data_path3 = "2020-08-07-B0447-S01-E01-T03.c3d"
data_path4 = "2020-08-07-B0448-S01-E01-T03.c3d"

data_path21 = "2020-08-05-B0444-S01-E02-T03.c3d"
data_path22 = "2020-08-06-B0445-S01-E02-T03.c3d"

data_path31 = "2020-08-05-B0444-S01-E03-T03.c3d"
data_path32 = "2020-08-06-B0445-S01-E03-T03.c3d"

data_path41 = "2020-08-05-B0444-S01-E04-T03.c3d"
data_path42 = "2020-08-06-B0445-S01-E04-T03.c3d"

data_path51 = "2020-08-05-B0444-S01-E05-T03.c3d"
data_path52 = "2020-08-06-B0445-S01-E05-T03.c3d"

c = c3d(data_path52)

# %%
print(c['parameters']['POINT']['LABELS']['value'][151:163])
# Out:
# ['B0445:RHipPower', 'B0445:RKneePower', 'B0445:RAnklePower', 'B0445:LWaistPower', 'B0445:RWaistPower', 'B0445:LNeckPower', 'B0445:RNeckPower', 'B0445:LShoulderPower', 'B0445:RShoulderPower', 'B0445:LElbowPower', 'B0445:RElbowPower', 'B0445:LWristPower']

# %%
import dataprocesing as dp

def wykresy_markerow(path):
    c = c3d(path)
    n_markers = ["LHipPower","LKneePower","LAnklePower","RHipPower","RKneePower","RAnklePower","LWaistPower","RWaistPower","LNeckPower","RNeckPower","LShoulderPower","RShoulderPower","LElbowPower","RElbowPower","LWristPower","RWristPower"]
    axes = ["x","y","z"]
    body = path.split('-')[3]+":"
    p,k = dp.read_labels(path,200)
    gg = -1
    for mark in n_markers:
        n = c['parameters']['POINT']['LABELS']['value'][:].index(body+mark)
        print(body+mark)
        gg = gg+1
        for i in range(3):
            
            for j in range(len(p)):
                plt.plot(c['data']['points'][i][n][p[j]:k[j]])
            plt.title("Oś "+axes[i]+"   "+n_markers[gg])
    
            plt.show()

# %%
wykresy_markerow(data_path52)
# Out:
# B0445:LHipPower
# B0445:LKneePower
# B0445:LAnklePower
# B0445:RHipPower
# B0445:RKneePower
# B0445:RAnklePower
# B0445:LWaistPower
# B0445:RWaistPower
# B0445:LNeckPower
# B0445:RNeckPower
# B0445:LShoulderPower
# B0445:RShoulderPower
# B0445:LElbowPower
# B0445:RElbowPower
# B0445:LWristPower
# B0445:RWristPower
